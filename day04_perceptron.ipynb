# %% [markdown]
# <a href="https://colab.research.google.com/github/redwanizazz/100-Days-of-DL/blob/main/day04_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# %%
import kagglehub
path = kagglehub.dataset_download("jessicali9530/animal-crossing-new-horizons-nookplaza-dataset")
# Out:
# Using Colab cache for faster access to the 'animal-crossing-new-horizons-nookplaza-dataset' dataset.

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
print(df.shape)
df.head()
# Out:
# (17000, 9)
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
X = df[['median_income', 'housing_median_age']]

y = df['median_house_value']

# %%
sns.scatterplot(data=df, x='median_income', y='median_house_value')
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
p = Perceptron()

# %%
y_class = (y > 200000).astype(np.int_)

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X.values)

p.fit(X_scaled, y_class.values)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 2.53309522, -0.4766987 ]])

# %%
p.intercept_
# Out:
# array([0.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_scaled, y_class.values, clf=p, legend=2)
# Out:
# <Axes: >

# %%
y_pred = p.predict(X_scaled)

acc = accuracy_score(y_class, y_pred)
print(f"Accuracy: {acc:.2%}")
# Out:
# Accuracy: 72.74%
